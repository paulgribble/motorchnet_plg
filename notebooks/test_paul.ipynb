# %%
import os
import sys 
sys.path.append(os.path.abspath('..'))
from utils import create_directory, plot_learning

# %%
# set the directory name same as you used for running the model.py
# it will save the data in your Documents/Data/directory_name folder
# here i used directory_name = 'try1' as the name
data_dir = create_directory(directory_name='paul_test')
# Out:
# Directory '/Users/plg/Documents/Data/paul_test3' already exists.

# %%
fig, ax = plot_learning(data_dir,num_model=16,w=100,figsize=(5,10))
fig.savefig(os.path.join(data_dir,'learning_curve.png'),dpi=300)
